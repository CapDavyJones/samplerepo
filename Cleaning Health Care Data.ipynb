# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Prince\Desktop\DataRelated\healthcare_messy_data.csv")

# %%
df
# Out:
#          Patient Name    Age  Gender      Condition    Medication  \
# 0          david lee      25   Other  Heart Disease     METFORMIN
# 1        emily davis     NaN    Male       Diabetes          NONE
# 2     laura martinez      35   Other         Asthma     METFORMIN
# 3     michael wilson     NaN    Male       Diabetes     ALBUTEROL
# 4          david lee     NaN  Female         Asthma          NONE
# ..                ...    ...     ...            ...           ...
# 995       mary clark      70   Other         Asthma     ALBUTEROL
# 996       mary clark   forty   Other            NaN    LISINOPRIL
# 997   laura martinez   forty   Other            NaN     ALBUTEROL
# 998       jane smith      25    Male            NaN     ALBUTEROL
# 999     james taylor   forty    Male       Diabetes  ATORVASTATIN
#
#         Visit Date Blood Pressure  Cholesterol               Email  \
# 0       01/15/2020         140/90        200.0   name@hospital.org
# ...

# %%
# Strip leading and trailing spaces from string columns 
for column in df.select_dtypes(include=['object']).columns: 
    df[column] = df[column].str.strip()

# %%
# Correct the Age column 
df['Age'] = df['Age'].replace('forty', 40)  # Replace 'forty' with 40
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')  # Convert to numeric, coercing errors to NaN

# Fill NaN values in the Age column before converting to int
df['Age'] = df['Age'].fillna(0).round(0).astype(int)  # Remove decimals and convert to int

# %%
# Correct the Blood Pressure column 
df['Blood Pressure'] = pd.to_numeric(df['Blood Pressure'], errors='coerce')
 
 # Correct the Cholesterol column 
df['Cholesterol'] = pd.to_numeric(df['Cholesterol'], errors='coerce')  # Convert to numeric, coercing errors to NaN

# Fill NaN values in the Cholesterol column before converting to int
df['Cholesterol'] = df['Cholesterol'].fillna(0).round(0).astype(int)  # Remove decimals and convert to int

# %%
# Standardise the Visit Date column 
df['Visit Date'] = pd.to_datetime(df['Visit Date'], errors='coerce')

# %%
# Fill NaN values with a default value or strategy 
df['Age'].fillna(df['Age'].mean(), inplace=True) 
df['Cholesterol'].fillna(df['Cholesterol'].mean(), inplace=True) 
 
 # Fill NaN values for categorical columns with a placeholder or most frequent value 
df['Gender'].fillna('Unknown', inplace=True) 
df['Condition'].fillna(df['Condition'].mode()[0], inplace=True) 
df['Medication'].fillna(df['Medication'].mode()[0], inplace=True) 
df['Blood Pressure'].fillna('120/80', inplace=True) 
df['Email'].fillna('no_email@example.com', inplace=True) 
df['Phone Number'].fillna('000-000-0000', inplace=True)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13864\314134176.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '120/80' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Blood Pressure'].fillna('120/80', inplace=True)

# %%
# Save the cleaned data to a new CSV file 
df.to_csv('cleaned_healthcare_data.csv', index=False)

# %%
df
# Out:
#        Patient Name  Age  Gender      Condition    Medication Visit Date  \
# 0         david lee   25   Other  Heart Disease     METFORMIN 2020-01-15
# 1       emily davis    0    Male       Diabetes          NONE        NaT
# 2    laura martinez   35   Other         Asthma     METFORMIN        NaT
# 3    michael wilson    0    Male       Diabetes     ALBUTEROL 2020-01-15
# 4         david lee    0  Female         Asthma          NONE        NaT
# ..              ...  ...     ...            ...           ...        ...
# 995      mary clark   70   Other         Asthma     ALBUTEROL        NaT
# 996      mary clark   40   Other         Asthma    LISINOPRIL 2020-01-15
# 997  laura martinez   40   Other         Asthma     ALBUTEROL        NaT
# 998      jane smith   25    Male         Asthma     ALBUTEROL        NaT
# 999    james taylor   40    Male       Diabetes  ATORVASTATIN        NaT
#
#     Blood Pressure  Cholesterol                 Email  Phone Number
# ...
